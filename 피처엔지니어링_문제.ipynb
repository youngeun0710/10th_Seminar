# %%
import pandas as pd

# 1. 데이터 로드 및 기본 정보 확인
# CSV 파일 불러오기

# %%
# 피처 추출 (독립변수 확인해보기)
df.
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 데이터프레임의 상위 5개 행을 출력하여 데이터의 기본 구조를 확인하시오.
# (빈칸: df.______())
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# 2. 피처 엔지니어링 1: 가족 수 변수 생성
# SibSp (형제자매 / 배우자 수) + Parch (부모 / 자녀 수) 값을 더하여 새로운 가족 수 변수를 만드시오.
# 변수 이름은 'Family_Size'로 지정하세요.

# Family_Size 변수의 분포를 확인하고, 전체적인 분포가 어떤지 설명하시오.

# %%
# 3. 피처 엔지니어링 2: 이름에서 호칭 추출
# 이름(`Name`)에서 Mr, Mrs, Miss 등 호칭을 추출하여 새로운 'Title' 변수를 생성하세요.
# 힌트: 이름 문자열에서 콤마(,)와 점(.) 사이의 텍스트를 추출하면 됨.
# (빈칸: df['Title'] = df['Name'].str.extract('_____', expand=False))

# 생성된 Title 변수의 상위 5개 값을 출력하고, 다양한 호칭이 어떻게 구성되어 있는지 확인하세요.
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\.'
# <>:5: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\binyb\AppData\Local\Temp\ipykernel_1228\18532891.py:5: SyntaxWarning: invalid escape sequence '\.'
#   df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
# 4. 피처 엔지니어링 3: 나이 그룹화
# Age 변수의 결측값을 중간값으로 채우고, 나이 범주를 나눠서 'Age_Group' 변수를 생성하세요.
# 예: 0-12 (Child), 13-18 (Teenager), 19-35 (Young_Adult), 36-60 (Adult), 60 이상 (Senior)
# (빈칸: df['Age'] = df['Age'].fillna(df['______.median()']))

# 나이를 그룹화하는 함수 작성


# age_group 함수를 사용하여 새로운 'Age_Group' 변수 생성
# (빈칸: df['Age_Group'] = df['Age'].apply(____))

# 생성된 Age_Group 변수의 분포를 확인하세요.
# (빈칸: print(df['______'].value_counts()))

# %%
# 5. 피처 엔지니어링 4: 요금 범주화
# Fare 변수를 기준으로 값이 높은 승객과 낮은 승객을 구분하기 위해 4개의 구간으로 나누어 'Fare_Bin' 변수를 생성하세요.
# 힌트: pd.qcut() 함수를 사용하여 구간 나누기
# (빈칸: df['Fare_Bin'] = pd.qcut(df['____'], _____))

# Fare_Bin 변수의 빈도를 출력하고, 값의 분포를 확인하세요.
# (빈칸: print(df['______'].value_counts()))

# %%
# 6. 피처 엔지니어링 5: 객실 여부
# Cabin 변수가 결측인 경우와 아닌 경우를 구분하여 'Cabin_Known' 변수를 생성하세요.
# Cabin 값이 존재하면 1, 결측이면 0으로 설정하세요.
# (빈칸: df['Cabin_Known'] = df['Cabin'].notna().astype(____))


# 생성된 Cabin_Known 변수의 빈도를 출력하고, 객실 여부와 생존율 간의 관계를 분석하세요.
# (빈칸: print(df['______'].value_counts()))

# %%
# 7. 피처 엔지니어링 6: 승선 지역
# 'Embarked' 변수를 더미 변수로 변환하여 승선 지역(S, C, Q)을 기준으로 각각의 더미 변수를 생성하세요.
# (빈칸: df = pd.get_dummies(df, columns=['____'], drop_first=True))

# 변환된 데이터프레임의 상위 5개 행을 출력하여 더미 변수 생성 결과를 확인하세요.
# (빈칸: df.______())
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare  Family_Size Title    Age_Group Fare_Bin  Cabin_Known  \
# 0   330911   7.8292            0    Mr  Young_Adult      Low            0
# 1   363272   7.0000            1   Mrs        Adult      Low            0
# 2   240276   9.6875            0    Mr       Senior      Mid            0
# 3   315154   8.6625            0    Mr  Young_Adult      Mid            0
# 4  3101298  12.2875            2   Mrs  Young_Adult      Mid            0
#
#    Embarked_Q  Embarked_S
# 0        True       False
# 1       False        True
# 2        True       False
# 3       False        True
# 4       False        True

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male  27.0      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male  27.0      0      0
# 417                      Peter, Master. Michael J    male  27.0      1      1
#
#                  Ticket      Fare  Family_Size   Title    Age_Group  \
# 0                330911    7.8292            0      Mr  Young_Adult
# 1                363272    7.0000            1     Mrs        Adult
# 2                240276    9.6875            0      Mr       Senior
# 3                315154    8.6625            0      Mr  Young_Adult
# 4               3101298   12.2875            2     Mrs  Young_Adult
# ..                  ...       ...          ...     ...          ...
# 413           A.5. 3236    8.0500            0      Mr  Young_Adult
# 414            PC 17758  108.9000            0    Dona        Adult
# 415  SOTON/O.Q. 3101262    7.2500            0      Mr        Adult
# 416              359309    8.0500            0      Mr  Young_Adult
# 417                2668   22.3583            2  Master  Young_Adult
#
#       Fare_Bin  Cabin_Known  Embarked_Q  Embarked_S
# 0          Low            0        True       False
# 1          Low            0       False        True
# 2          Mid            0        True       False
# 3          Mid            0       False        True
# 4          Mid            0       False        True
# ..         ...          ...         ...         ...
# 413        Mid            0       False        True
# 414  Very_High            1       False       False
# 415        Low            0       False        True
# 416        Mid            0       False        True
# 417       High            0       False       False
#
# [418 rows x 17 columns]

# %% [markdown]
# ## 문제

# %% [markdown]
# ### 1. 피처엔지니어링을 통해 기대할 수 있는 효과는 무엇인지 설명하시오.

# %% [markdown]
# ### 2. 새로 생성한 변수에 대해 간단히 설명하고 모델의 성능이 향상된다면 그 이유가 무엇일지 설명하시오.
